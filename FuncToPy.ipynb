# %%
def y(x=5):
    return x

y()
# Out:
# 5

# %%
def y (x):
    return x

y(10)
# Out:
# 10

# %%
def y (a,b,c,x):
    return a*x**2+(b*x)+c

y(10,5,6,5)
# Out:
# 281

# %%
def y (a,b,c,d,x):
    return a*x**3+b*x**2+c*x+d

y(5,8,4,2,3)
# Out:
# 221

# %%
def y (a,x):
    return a**x

y(5,3)
# Out:
# 125

# %%
def y (x):
    return -x

y(10)
# Out:
# -10

# %%
def y (a,d,f,w):
    return w-a*d/f

y(6,5,11,3)
# Out:
# 0.27272727272727293

# %%
def y (a,b,x,z):
    return a*x+b*z

y(4,9,7,37)
# Out:
# 361
